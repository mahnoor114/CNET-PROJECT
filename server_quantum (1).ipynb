# %%
# SERVER NOTEBOOK
import socket
import os

# === CONFIGURATION ===
HOST = '127.0.0.1'   # localhost
PORT = 5001
FILE_PATH = r"C:\wireshark\synthetic_data_1mb.bin"

# Create socket
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)  # allow reuse
    s.bind((HOST, PORT))
    s.listen()
    print(f"[SERVER] Listening on {HOST}:{PORT}")

    conn, addr = s.accept()
    with conn:
        print(f"[SERVER] Connected by {addr}")

        # Send file size first
        file_size = os.path.getsize(FILE_PATH)
        conn.sendall(str(file_size).encode() + b'\n')

        # Send the file in chunks
        with open(FILE_PATH, 'rb') as f:
            while chunk := f.read(1024):
                conn.sendall(chunk)

        print("[SERVER] File transfer completed")
# Out:
# [SERVER] Listening on 127.0.0.1:5001
# [SERVER] Connected by ('127.0.0.1', 57230)
# [SERVER] File transfer completed

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 # QUANTUM NOTEBOOK
#       2 # Quantum Communication: Superdense Coding & Teleportation
# ----> 3 from qiskit import QuantumCircuit, transpile, assemble
#       4 from qiskit.providers.aer import AerSimulator
#       6 # ----------------------------
#       7 # Superdense Coding
#       8 # ----------------------------
#
# ImportError: cannot import name 'assemble' from 'qiskit' (C:\Users\mahno\anaconda3\Lib\site-packages\qiskit\__init__.py)
